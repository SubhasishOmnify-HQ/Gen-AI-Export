# %% [raw]
# Word embeddings convert words into dense numerical vectors that capture semantic relationships.

# %% [markdown]
# # Main Word Embedding Methods

# %% [raw]
# 1. Word2Vec
#
# Two approaches:
#
# Word2Vec
#    ├── CBOW
#    └── Skip-gram
# 2. GloVe
#
# Uses global word co-occurrence statistics.
#
# 3. FastText
#
# Uses subword information, making it useful for rare and unknown words.
#
# 4. Contextual Embeddings

# %% [markdown]
# # Word2Vec
